# %%
import numpy as np
import math
from scipy import optimize
import matplotlib.pylab as plt
# %matplotlib inline

def f(x):
    return math.sin(x/5.0) * math.exp(x/10.0) * 5*math.exp(-x/2.0)

z = optimize.minimize(f, [30], method='BFGS')

ran = np.arange(0., 30., 0.2)

plt.plot(ran, [f(i) for i in ran])
plt.show()

# %%
z
# Out:
#       fun: -8.583940778725981e-06
#  hess_inv: array([[1]])
#       jac: array([  9.33306592e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 3
#       nit: 0
#      njev: 1
#    status: 0
#   success: True
#         x: array([ 30.])

# %%
z = optimize.minimize(f, [0], method='BFGS')

# %%
optimize.minimize(f, [0], method='BFGS')
# Out:
#       fun: -473.7165018473426
#  hess_inv: array([[ 0.01056368]])
#       jac: array([ 0.])
#   message: 'Optimization terminated successfully.'
#      nfev: 39
#       nit: 3
#      njev: 13
#    status: 0
#   success: True
#         x: array([-13.38972542])

# %%
ran = np.arange(0., 30., 0.2)

plt.plot(ran, [f(i) for i in ran])
plt.show()

# %%
optimize.minimize(f, [2], method='BFGS')
# Out:
#       fun: -473.71650184734455
#  hess_inv: array([[ 0.01307884]])
#       jac: array([  7.62939453e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 66
#       nit: 5
#      njev: 22
#    status: 0
#   success: True
#         x: array([-13.38972522])

# %%
import numpy as np
import math
from scipy import optimize
import matplotlib.pylab as plt

def f(x):
    return math.sin(x/5.0) * math.exp(x/10.0) + 5*math.exp(-x/2.0)

z = optimize.minimize(f, [30], method='BFGS')

ran = np.arange(0., 30., 0.1)

plt.plot(ran, [f(i) for i in ran])
plt.show()

# %%
z
# Out:
#       fun: -11.898894665981285
#  hess_inv: array([[ 1.67932484]])
#       jac: array([  2.38418579e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 21
#       nit: 6
#      njev: 7
#    status: 0
#   success: True
#         x: array([ 25.88019339])

# %%
z = optimize.minimize(f, [2], method='BFGS')

# %%
z
# Out:
#       fun: 1.7452682903449388
#  hess_inv: array([[ 5.98752437]])
#       jac: array([ -2.07126141e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 21
#       nit: 6
#      njev: 7
#    status: 0
#   success: True
#         x: array([ 4.13627618])

# %%
z = optimize.differential_evolution(f, [(1, 30)])

# %%
z
# Out:
#      fun: -11.898894665981322
#      jac: array([ -1.77635684e-07])
#  message: 'Optimization terminated successfully.'
#     nfev: 96
#      nit: 5
#  success: True
#        x: array([ 25.880193])

# %%
ran = np.arange(0., 30., 0.1)

plt.plot(ran, [int(f(i)) for i in ran])
plt.show()

# %%
z = optimize.minimize(f, [30], method='BFGS')

# %%
z
# Out:
#       fun: -11.898894665981285
#  hess_inv: array([[ 1.67932484]])
#       jac: array([  2.38418579e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 21
#       nit: 6
#      njev: 7
#    status: 0
#   success: True
#         x: array([ 25.88019339])

# %%
optimize.differential_evolution(int(f, [(1, 30)])
